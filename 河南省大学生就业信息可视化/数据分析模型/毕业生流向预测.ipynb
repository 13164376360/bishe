# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#读取数据
df = pd.read_excel('gofor.xlsx')
df  # data frame
df.head()
print(df)
# Out:
#      level      to      from
# 0        3  0.0112  0.016400
# 1        3  0.0003  0.000000
# 2        2  0.0396  0.002900
# 3        3  0.0163  0.015100
# 4        3  0.0071  0.019700
# ..     ...     ...       ...
# 129      3  0.0002  0.000000
# 130      3  0.0022  0.006019
# 131      3  0.0043  0.003802
# 132      3  0.0236  0.000000
# 133      3  0.0022  0.000158
#
# [134 rows x 3 columns]

# %%
matrix = df.corr()
f, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(matrix, square=True)
plt.title('city')
# Out:
# Text(0.5, 1, 'city')

# %%
# 训练模型
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import numpy as np
# d=d.reshape(-1,1)
X = df[['to', 'from']].values
y = df['level'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2003)
clf = KNeighborsClassifier(n_neighbors=2)
clf.fit(X_train, y_train)
d=[[0.4528,0.5852]]
# k1=clf.kneighbors(x1,return_distance=False)
print(clf.predict(d))
# Out:
# [1]
# C:\ruanjiananzhuang\anaconda3\lib\site-packages\ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if sys.path[0] == '':

# %%
from sklearn.metrics import accuracy_score
correct = np.count_nonzero((clf.predict(X_test)==y_test)==True)
#accuracy_score(y_test, clf.predict(X_test))
print ("Accuracy is: %.3f" %(correct/len(X_test)))
# Out:
# Accuracy is: 24.500

# %%
plt.figure(figsize =(16,14),dpi=144)
a=np.arange(0,1,0.01)
plt.scatter(X[:,0],X[:,1],)
plt.plot(a,a)
plt.scatter
# Out:
# <function matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, plotnonfinite=False, data=None, **kwargs)>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
plt.figure(figsize=(16, 8))
plt.scatter(df['to'], df['from'], c ='black')
plt.xlabel("to values")
plt.ylabel("valus of from")
plt.show()

# %%
X = df['to'].values.reshape(-1,1)
y = df['from'].values.reshape(-1,1)

reg = LinearRegression()
reg.fit(X, y)
print('a = {:.5}'.format(reg.coef_[0][0]))
print('b = {:.5}'.format(reg.intercept_[0]))

print("线性模型为: Y = {:.5}X + {:.5} ".format(reg.coef_[0][0], reg.intercept_[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-58dd843a0582> in <module>
#       2 y = df['from'].values.reshape(-1,1)
#       3
# ----> 4 reg = LinearRegression()
#       5 reg.fit(X, y)
#       6 print('a = {:.5}'.format(reg.coef_[0][0]))
#
# NameError: name 'LinearRegression' is not defined

# %%
predictions = reg.predict(X)

plt.figure(figsize=(16, 8))
plt.scatter(df['GPA'], df['pay'], c ='black')
plt.plot(df['GPA'], predictions,c ='blue', linewidth=2)
plt.xlabel("GPA")
plt.ylabel("pay")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8b68134a1847> in <module>
# ----> 1 predictions = reg.predict(X)
#       2
#       3 plt.figure(figsize=(16, 8))
#       4 plt.scatter(df['GPA'], df['pay'], c ='black')
#       5 plt.plot(df['GPA'], predictions,c ='blue', linewidth=2)
#
# NameError: name 'reg' is not defined
